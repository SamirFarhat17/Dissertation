# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import plotly.graph_objects as go
from plotly.colors import n_colors
# Out:
# /home/samir/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
dates = range(0,365)

bitcoin_data_path = os.path.join(os.getcwd(),'Data', 'BTC_USD_2019-11-29_2020-11-28-CoinDesk.csv')
bitcoin = pd.read_csv(bitcoin_data_path)
btc_values = bitcoin['24h Open (USD)'].values

euro_data_path = os.path.join(os.getcwd(), 'Data','eurotodollar.csv')
euro = pd.read_csv(euro_data_path)
euro_values = euro['Open'].values *10000

gbp_data_path = os.path.join(os.getcwd(), 'Data','gbptodollar.csv')
gbp = pd.read_csv(gbp_data_path)
gbp_values = gbp['Open'].values *10000

aud_data_path = os.path.join(os.getcwd(), 'Data','auddollar.csv')
aud = pd.read_csv(aud_data_path)
aud_values = aud['Open'].values *10000

# %%
fig, bitcoin_stuff = plt.subplots(figsize =(15,7))
bitcoin_stuff.plot(dates,btc_values)
bitcoin_stuff.plot(dates,euro_values)
bitcoin_stuff.plot(dates,gbp_values)
bitcoin_stuff.plot(dates,aud_values)

bitcoin_stuff.set_ylim([0,20000])
bitcoin_stuff.set_xlim([0,365])

plt.legend(['BTC', 'EUR', 'GBP', 'AUD'], loc='lower right')
plt.xlabel('1 year period')
plt.ylabel('Price of asset in USD')
# Out:
# Text(0, 0.5, 'Price of asset in USD')

# %%
headerColor = 'grey'
rowEvenColor = 'lightgrey'
rowOddColor = 'lightgoldenrodyellow'

fig = go.Figure(data=[go.Table(
  header=dict(
    values=['<b>Coin</b>','<b>Class</b>','<b>Mechanism</b>','<b>Market Cap Rank</b>'],
    line_color='white',
    fill_color=headerColor,
    align=['center'],
    font=dict(color='white', size=14)
  ),
  cells=dict(
    values=[['USDC', 'TrueUSD', 'Paxos', 'GeminiDollar', 'Tether','EURSToken'
       ,'Dai', 'BitUSD','RSCoin','NuBits','CarbonUSD'],
        
      ['Backed', 'Backed', 'Backed', 'Backed', 'Backed','Backed'
       ,'Backed', 'Backed','Intervention','Intervention','Intervention'],
        
      ['Directly-backed, Redeemable', 'Directly-backed, Redeemable', 
       'Directly-backed, Redeemable', 'Directly-backed, Redeemable', 
       'Directly-backed','Directly-backed','Indirectly-backed', 
       'Indirectly-backed','Money Supply Adjustments','Asset Transfer','Asset Transfer'],
        
      ['20', '26', '38', '52', '6','95'
       ,'57', '398','Not public','892','1262']],
    line_color='white',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor,rowOddColor, rowEvenColor,
                   rowOddColor,rowEvenColor,rowOddColor,rowEvenColor, rowOddColor,rowEvenColor, rowOddColor]],
    align = [ 'center'],
    font = dict(color = 'black', size = 12),
))
])
fig.show()
# Out:
# <div>                            <div id="7e04631b-acf9-43ea-9788-ca9ad9ea7bf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e04631b-acf9-43ea-9788-ca9ad9ea7bf3")) {                    Plotly.newPlot(                        "7e04631b-acf9-43ea-9788-ca9ad9ea7bf3",                        [{"cells": {"align": ["center"], "fill": {"color": [["lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow"]]}, "font": {"color": "black", "size": 12}, "line": {"color": "white"}, "values": [["USDC", "TrueUSD", "Paxos", "GeminiDollar", "Tether", "EURSToken", "Dai", "BitUSD", "RSCoin", "NuBits", "CarbonUSD"], ["Bac
# ...

# %%
dates = range(0,365)

tether_data_path = os.path.join(os.getcwd(),'Data', 'USDT_USD_2019-11-30_2020-11-29-CoinDesk.csv')
tether = pd.read_csv(tether_data_path)
usdt_values = tether['24h Open (USD)'].values

euro_data_path = os.path.join(os.getcwd(), 'Data','eurotodollar.csv')
euro = pd.read_csv(euro_data_path)
euro_values = euro['Open'].values

gbp_data_path = os.path.join(os.getcwd(), 'Data','gbptodollar.csv')
gbp = pd.read_csv(gbp_data_path)
gbp_values = gbp['Open'].values

aud_data_path = os.path.join(os.getcwd(), 'Data','auddollar.csv')
aud = pd.read_csv(aud_data_path)
aud_values = aud['Open'].values

# %%
fig, tether_stuff = plt.subplots(figsize =(15,7))
tether_stuff.plot(dates,usdt_values)
tether_stuff.plot(dates,euro_values)
tether_stuff.plot(dates,gbp_values)
tether_stuff.plot(dates,aud_values)

tether_stuff.set_ylim([.5,1.5])
tether_stuff.set_xlim([0,365])

plt.legend(['USDT', 'EUR', 'GBP', 'AUD'], loc='lower right')
plt.xlabel('1 year period')
plt.ylabel('Price of asset in USD')
# Out:
# Text(0, 0.5, 'Price of asset in USD')

# %%
headerColor = 'grey'
rowEvenColor = 'lightgrey'
rowOddColor = 'lightgoldenrodyellow'

colors = n_colors('rgb(255, 0, 0)', 'rgb(0, 255, 0)', 9, colortype='rgb')

figure = go.Figure(data=[go.Table(
  header=dict(
    values=['<b>Type</b>','<b>Corrects Undervaluation</b>',
            '<b>Corrects Overvaluation</b>',
            '<b>Decentralizes Issuance</b>','<b>Decentralizes Redemption</b>',
            '<b>Decentralizes Transfer</b>','<b>No Trusted Oracle</b>'],
    line_color='white',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=14)
  ),
  cells=dict(
    values=[
      ['Traditional Digital Cash', 'Traditional Cryptocurrency', 
       'Directly Backed & Redeemable', 'Directly Backed', 'Indirectly Backed',
       'Money Supply Adjustments','Asset transfer'],
      [u'\u2713', 'x', u'\u2713', 'x', u'\u2713','Depends' ,'Depends'],
      [u'\u2713', 'x', u'\u2713', u'\u2713', u'\u2713',u'\u2713' ,u'\u2713'],
      ['x', u'\u2713', 'x', 'x', u'\u2713',u'\u2713' ,u'\u2713'],
      [u'\u2713', 'N/A', 'x', 'x', u'\u2713', 'N/A', 'N/A'],
      ['x', u'\u2713', u'\u2713', u'\u2713', u'\u2713',u'\u2713' ,u'\u2713'],
      [u'\u2713', u'\u2713', u'\u2713', u'\u2713', 'x',u'\u2713' ,u'\u2713']],
    line_color='white',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor,rowOddColor, rowEvenColor,rowOddColor,rowEvenColor,rowOddColor]],
    align = ['left','center'],
    font = dict(color = 'black', size = 12),
))
])
figure.update_layout(width=1100, height=700)
figure.show()
# Out:
# <div>                            <div id="ec366802-d9fe-462c-bf73-0ed2a765c96c" class="plotly-graph-div" style="height:700px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec366802-d9fe-462c-bf73-0ed2a765c96c")) {                    Plotly.newPlot(                        "ec366802-d9fe-462c-bf73-0ed2a765c96c",                        [{"cells": {"align": ["left", "center"], "fill": {"color": [["lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow", "lightgrey", "lightgoldenrodyellow"]]}, "font": {"color": "black", "size": 12}, "line": {"color": "white"}, "values": [["Traditional Digital Cash", "Traditional Cryptocurrency", "Directly Backed & Redeemable", "Directly Backed", "Indirectly Backed", "Money Supply Adjustments", "Asset transfer"], ["\u2713",
# ...

# %%
dates = range(0,365)

dai_data_path = os.path.join(os.getcwd(),'Data', 'dai-usd-max.csv')
dai = pd.read_csv(dai_data_path)
dai = dai[:365]
dai_values = dai['price'].values

# %%
fig, dai_stuff = plt.subplots(figsize =(15,7))
dai_stuff.plot(dates,dai_values)
dai_stuff.set_ylim([.5,1.5])
dai_stuff.set_xlim([0,365])

plt.xlabel('1 year period')
plt.ylabel('Price of Dai in USD')
# Out:
# Text(0, 0.5, 'Price of Dai in USD')

# %%
mkr_data_path = os.path.join(os.getcwd(),'Data', 'mkr-usd-max.csv')
mkr = pd.read_csv(mkr_data_path)
mkr = mkr.tail(365)
mkr_values = mkr['price'].values

# %%
fig, mkr_stuff = plt.subplots(figsize =(15,7))
mkr_stuff.plot(dates,mkr_values)
#mkr_stuff.set_ylim([.5,1.5])
mkr_stuff.set_xlim([0,365])

plt.xlabel('1 year period')
plt.ylabel('Price of MKR in USD')
# Out:
# Text(0, 0.5, 'Price of MKR in USD')

# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch

# %%
q_max = m.quantity() * 2
q_grid = np.linspace(0.0, q_max, 100)

pd = m.inverse_demand(q_grid)
ps = m.inverse_supply(q_grid)

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(q_grid, pd, lw=2, alpha=0.6, label='Demand', color='red')
ax.plot(q_grid, ps, lw=2, alpha=0.6, label='Supply', color='blue')

ax.set_xlabel('Quantity')
ax.set_xlim(0, q_max)
ax.set_ylabel('Price')
ax.legend(loc='best')
ax.set_yticklabels([])
ax.set_xticklabels([])
# Out:
# [Text(0.0, 0, ''),
#  Text(2.0, 0, ''),
#  Text(4.0, 0, ''),
#  Text(6.0, 0, ''),
#  Text(8.0, 0, ''),
#  Text(10.0, 0, ''),
#  Text(12.0, 0, ''),
#  Text(14.0, 0, '')]
